# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cleaning Reaction table

# %%
df_reactions = pd.read_csv('Reactions.csv')

# %%
df_reactions
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# ...

# %%
df_reactions.isna().sum()
# Out:
# Unnamed: 0       0
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
df_reactions= df_reactions.dropna(subset=['Type'])

# %%
df_reactions.isna().sum()
# Out:
# Unnamed: 0       0
# Content ID       0
# User ID       2039
# Type             0
# Datetime         0
# dtype: int64

# %%
df_1 = df_reactions[df_reactions['User ID'].isna()]

# %%
df_1
# Out:
#        Unnamed: 0                            Content ID User ID        Type  \
# 10             10  97522e57-d9ab-4bd6-97bf-c24d952602d2     NaN        love
# 20             20  97522e57-d9ab-4bd6-97bf-c24d952602d2     NaN   intrigued
# 30             30  97522e57-d9ab-4bd6-97bf-c24d952602d2     NaN   intrigued
# 40             40  97522e57-d9ab-4bd6-97bf-c24d952602d2     NaN     dislike
# 56             56  9f737e0a-3cdd-4d29-9d24-753f4e3be810     NaN        love
# ...           ...                                   ...     ...         ...
# 25509       25509  4e4c9690-c013-4ee7-9e66-943d8cbd27b7     NaN     dislike
# 25519       25519  4e4c9690-c013-4ee7-9e66-943d8cbd27b7     NaN        love
# 25529       25529  4e4c9690-c013-4ee7-9e66-943d8cbd27b7     NaN     dislike
# 25539       25539  4e4c9690-c013-4ee7-9e66-943d8cbd27b7     NaN     cherish
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56     NaN  interested
#
#                   Datetime
# 10     2020-08-04 05:05:02
# ...

# %%
df_reactions['User ID']=df_reactions['User ID'].fillna('Unknown')
# Out:
# C:\Users\aanch\AppData\Local\Temp\ipykernel_35184\2491005117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reactions['User ID']=df_reactions['User ID'].fillna('Unknown')

# %%
df_reactions
# Out:
#        Unnamed: 0                            Content ID  \
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# ...

# %%
df_reactions.duplicated().sum()
# Out:
# 0

# %%
df_reactions['Datetime']=pd.to_datetime(df_reactions['Datetime'])
# Out:
# C:\Users\aanch\AppData\Local\Temp\ipykernel_35184\3676355918.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reactions['Datetime']=pd.to_datetime(df_reactions['Datetime'])

# %%
df_reactions['Month']=df_reactions['Datetime'].dt.month
# Out:
# C:\Users\aanch\AppData\Local\Temp\ipykernel_35184\3825405281.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reactions['Month']=df_reactions['Datetime'].dt.month

# %%
df_reactions
# Out:
#        Unnamed: 0                            Content ID  \
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5               5  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime  \
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# ...

# %%
df_reactions.drop(['Unnamed: 0','User ID','Datetime'],axis=1,inplace=True)
# Out:
# C:\Users\aanch\AppData\Local\Temp\ipykernel_35184\684171890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reactions.drop(['Unnamed: 0','User ID','Datetime'],axis=1,inplace=True)

# %%
df_reactions
# Out:
#                                  Content ID        Type  Month
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust     11
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike      6
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2      scared      4
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust      1
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2  interested      8
# ...                                     ...         ...    ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike      6
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued      2
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56  interested      9
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56     worried     11
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish      1
#
# [24573 rows x 3 columns]

# %%
df_reactions['Type'].nunique()
# Out:
# 16

# %%
df_reactions['Type'].value_counts()
# Out:
# heart          1622
# scared         1572
# peeking        1559
# hate           1552
# interested     1549
# dislike        1548
# adore          1548
# want           1539
# love           1534
# disgust        1526
# like           1520
# super love     1519
# indifferent    1512
# cherish        1501
# worried        1497
# intrigued      1475
# Name: Type, dtype: int64

# %%
df_reactions=df_reactions.rename({'Type':'Reaction Type'},axis=1)

# %%
df_reactions
# Out:
#                                  Content ID Reaction Type  Month
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust     11
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike      6
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared      4
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust      1
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested      8
# ...                                     ...           ...    ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike      6
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued      2
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56    interested      9
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56       worried     11
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish      1
#
# [24573 rows x 3 columns]

# %% [markdown]
# ## Cleaning Reaction types table

# %%
df_reaction_type = pd.read_csv('ReactionTypes.csv')

# %%
df_reaction_type
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
df_reaction_type.drop(['Unnamed: 0','Sentiment'],axis=1,inplace=True)

# %%
df_reaction_type = df_reaction_type.rename({'Type':'Reaction Type'},axis=1)

# %%
df_reaction_type
# Out:
#    Reaction Type  Score
# 0          heart     60
# 1           want     70
# 2        disgust      0
# 3           hate      5
# 4     interested     30
# 5    indifferent     20
# 6           love     65
# 7     super love     75
# 8        cherish     70
# 9          adore     72
# 10          like     50
# 11       dislike     10
# 12     intrigued     45
# 13       peeking     35
# 14        scared     15
# 15       worried     12

# %% [markdown]
# ## Cleaning Content table

# %%
df_content = pd.read_csv('Content.csv')

# %%
df_content
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
df_content=df_content.drop(['Unnamed: 0','User ID','URL'],axis=1)

# %%
df_content=df_content.rename({'Type':'Content Type'},axis=1)

# %%
df_content
# Out:
#                                Content ID Content Type         Category
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2        photo         Studying
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo   healthy eating
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f        photo   healthy eating
# 3    356fff80-da4d-4785-9f43-bc1261031dc6        photo       technology
# 4    01ab84dd-6364-4236-abbb-3f237db77180        video             food
# ..                                    ...          ...              ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb        video  public speaking
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c          GIF       technology
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b        audio         veganism
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF          culture
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56        audio       technology
#
# [1000 rows x 3 columns]

# %%
df_content.isna().sum()
# Out:
# Content ID      0
# Content Type    0
# Category        0
# dtype: int64

# %%
df_content.duplicated().sum()
# Out:
# 0

# %%
df_combi1 = df_reactions.merge(df_reaction_type,on='Reaction Type')

# %%
df_combi1
# Out:
#                                  Content ID Reaction Type  Month  Score
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust     11      0
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust      1      0
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust      4      0
# 3      9f737e0a-3cdd-4d29-9d24-753f4e3be810       disgust      3      0
# 4      230c4e4d-70c3-461d-b42c-ec09396efb3f       disgust      8      0
# ...                                     ...           ...    ...    ...
# 24568  435007a5-6261-4d8b-b0a4-55fdc189754b         adore     10     72
# 24569  435007a5-6261-4d8b-b0a4-55fdc189754b         adore      9     72
# 24570  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore     10     72
# 24571  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore      6     72
# 24572  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore     12     72
#
# [24573 rows x 4 columns]

# %%
final_df = df_content.merge(df_combi1,on='Content ID')

# %%
final_df
# Out:
#                                  Content ID Content Type    Category  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# ...                                     ...          ...         ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
#
#       Reaction Type  Month  Score
# 0           disgust     11      0
# 1           disgust      1      0
# ...

# %%
final_df.isna().sum()
# Out:
# Content ID       0
# Content Type     0
# Category         0
# Reaction Type    0
# Month            0
# Score            0
# dtype: int64

# %%
final_df.duplicated().sum()
# Out:
# 1921

# %%
duplicated_df=final_df[final_df.duplicated]

# %%
duplicated_df
# Out:
#                                  Content ID Content Type        Category  \
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo        Studying
# 9      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo        Studying
# 10     97522e57-d9ab-4bd6-97bf-c24d952602d2        photo        Studying
# 36     97522e57-d9ab-4bd6-97bf-c24d952602d2        photo        Studying
# 49     9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo  healthy eating
# ...                                     ...          ...             ...
# 24508  435007a5-6261-4d8b-b0a4-55fdc189754b        audio        veganism
# 24526  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF         culture
# 24531  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF         culture
# 24544  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF         culture
# 24546  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF         culture
#
#       Reaction Type  Month  Score
# 5           dislike     11     10
# ...

# %%
final_df=final_df.drop_duplicates()

# %%
final_df
# Out:
#                                  Content ID Content Type    Category  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# ...                                     ...          ...         ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
#
#       Reaction Type  Month  Score
# 0           disgust     11      0
# 1           disgust      1      0
# ...

# %%
final_df.to_csv('Top_5_categories.csv', index= False)

# %%
top5_df=pd.read_csv('Top_5_categories.csv')

# %%
top5_df
# Out:
#                                  Content ID Content Type    Category  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# ...                                     ...          ...         ...
# 22647  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 22648  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 22649  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 22650  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 22651  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
#
#       Reaction Type  Month  Score
# 0           disgust     11      0
# 1           disgust      1      0
# ...

# %%
month=top5_df['Month'].value_counts().reset_index()
month
# Out:
#     index  Month
# 0       1   1979
# 1       8   1957
# 2       5   1942
# 3      12   1920
# 4       7   1912
# 5      10   1889
# 6      11   1874
# 7       6   1871
# 8       9   1861
# 9       3   1851
# 10      4   1823
# 11      2   1773

# %%
x=month['index'].sort_values()
y=month['Month']
label=['Jan','Feb','March','April','May','June','July','Aug','Sept','Oct','Nov','Dec']
plt.figure(figsize=(8,5))
plt.bar(x,y)
plt.xticks(x,label)
for i, popu in enumerate(y):
    plt.text(i+1, popu, str(popu), ha='center',va='bottom')
plt.title('Month with most number of Posts')
plt.xlabel('Months')
plt.ylabel('Number of posts')
plt.show()

# %%
top5_df['Category']=top5_df['Category'].str.lower()

# %%
top5_df['Category']=top5_df['Category'].str.replace('"','')

# %%
top5_df['Category'].value_counts()
# Out:
# animals            1735
# science            1657
# healthy eating     1577
# technology         1563
# food               1549
# culture            1536
# cooking            1534
# travel             1518
# soccer             1359
# education          1342
# fitness            1300
# studying           1253
# dogs               1234
# tennis             1224
# veganism           1151
# public speaking    1120
# Name: Category, dtype: int64

# %%
top5_df
# Out:
#                                  Content ID Content Type    Category  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    studying
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    studying
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    studying
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    studying
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    studying
# ...                                     ...          ...         ...
# 22647  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 22648  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 22649  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 22650  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 22651  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
#
#       Reaction Type  Month  Score
# 0           disgust     11      0
# 1           disgust      1      0
# ...

# %%
category_score = top5_df.groupby('Category')['Score'].sum()

# %%
category_score_sorted = category_score.sort_values(ascending=False)

# %%
category_score_sorted
# Out:
# Category
# animals            68129
# science            65564
# healthy eating     63809
# technology         62980
# culture            61289
# food               60879
# travel             59975
# cooking            59917
# soccer             53987
# education          53811
# fitness            51687
# studying           50215
# dogs               48415
# tennis             46323
# veganism           45655
# public speaking    45202
# Name: Score, dtype: int64

# %%
plt.figure(figsize=(25,8))
plt.bar(category_score_sorted.index,category_score_sorted.values)
plt.xlabel('Categories')
plt.ylabel('Scores')
plt.title('Top 5 Categories')
plt.show()

# %%
top5_categories = ['animals','science','technology','travel','healthy eating']

# %%
clean_df=top5_df.loc[top5_df['Category'].isin(top5_categories)]

# %%
clean_df
# Out:
#                                  Content ID Content Type        Category  \
# 41     9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo  healthy eating
# 42     9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo  healthy eating
# 43     9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo  healthy eating
# 44     9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo  healthy eating
# 45     9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo  healthy eating
# ...                                     ...          ...             ...
# 22647  75d6b589-7fae-4a6d-b0d0-752845150e56        audio      technology
# 22648  75d6b589-7fae-4a6d-b0d0-752845150e56        audio      technology
# 22649  75d6b589-7fae-4a6d-b0d0-752845150e56        audio      technology
# 22650  75d6b589-7fae-4a6d-b0d0-752845150e56        audio      technology
# 22651  75d6b589-7fae-4a6d-b0d0-752845150e56        audio      technology
#
#       Reaction Type  Month  Score
# 41          disgust      3      0
# ...

# %%
clean_df.to_csv('Cleaned Data with top 5 category.csv')

# %%
list1=category_score_sorted.index

# %%
list1
# Out:
# Index(['animals', 'science', 'healthy eating', 'technology', 'culture', 'food',
#        'travel', 'cooking', 'soccer', 'education', 'fitness', 'studying',
#        'dogs', 'tennis', 'veganism', 'public speaking'],
#       dtype='object', name='Category')

# %%
def category_score():
    for i in list1:
        new_df = top5_df[top5_df['Category'] == i]
        count=new_df['Content Type'].value_counts()
        plt.pie(count.values, labels=count.index, autopct= '%1.1f%%')
        plt.title(i)
        plt.show()

# %%
category_score()

# %%
count = clean_df.groupby('Category')['Score'].sum()

# %%
count
# Out:
# Category
# animals           68129
# healthy eating    63809
# science           65564
# technology        62980
# travel            59975
# Name: Score, dtype: int64

# %%
count.values
# Out:
# array([68129, 63809, 65564, 62980, 59975], dtype=int64)

# %%
plt.bar(count.index,count.values)

for i, x in enumerate(count.values):
    plt.text(i , x, str(x), ha='center', va='bottom')
plt.title('Reactions to the most popular category')
plt.show()
